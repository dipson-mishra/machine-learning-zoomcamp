# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
path='https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/course_lead_scoring_2026.csv'

# %%
df=pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lead_source               4852 non-null   str
#  1   industry                  4760 non-null   str
#  2   employment_status         4806 non-null   str
#  3   location                  4792 non-null   str
#  4   annual_income             4631 non-null   float64
#  5   number_of_courses_viewed  5000 non-null   int64
#  6   interaction_count         5000 non-null   int64
#  7   lead_score                4965 non-null   float64
#  8   converted                 5000 non-null   int64
# dtypes: float64(2), int64(3), str(4)
# memory usage: 351.7 KB

# %%
df.isna().sum()
# Out:
# lead_source                 148
# industry                    240
# employment_status           194
# location                    208
# annual_income               369
# number_of_courses_viewed      0
# interaction_count             0
# lead_score                   35
# converted                     0
# dtype: int64

# %%
categorical=['lead_source','industry','employment_status','location']
numerical=['annual_income','number_of_courses_viewed','interaction_count','lead_score','converted']

# %%
df[numerical]=df[numerical].fillna(0)
df[categorical]=df[categorical].fillna('NA')

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Question 1
# What is the most frequent observation (mode) for the column industry?
#
# - NA
# - technology
# - healthcare
# - retail

# %%
df['industry'].mode()
# Out:
# 0    technology
# Name: industry, dtype: str

# %% [markdown]
# # Question 2
# Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features.
# <br><br>
#
# What are the two features that have the biggest correlation?
# - interaction_count and lead_source
# - number_of_courses_viewed and lead_source
# - number_of_courses_viewed and interaction_count
# - annual_income and interaction_count<br>
# Only consider the pairs above when answering this question.

# %%
corr_matrix = (
    df
    .select_dtypes("number") # to select the numeric data only
    .corr()
)
print(corr_matrix)
# Out:
#                           annual_income  number_of_courses_viewed  \
# annual_income                  1.000000                  0.161300
# number_of_courses_viewed       0.161300                  1.000000
# interaction_count              0.122842                  0.721609
# lead_score                     0.229496                  0.757204
# converted                      0.189652                  0.395038
#
#                           interaction_count  lead_score  converted
# annual_income                      0.122842    0.229496   0.189652
# number_of_courses_viewed           0.721609    0.757204   0.395038
# interaction_count                  1.000000    0.915746   0.448624
# lead_score                         0.915746    1.000000   0.483246
# converted                          0.448624    0.483246   1.000000

# %%
df[categorical].nunique()
# Out:
# lead_source          6
# industry             7
# employment_status    5
# location             6
# dtype: int64

# %%
df[categorical].head(10)
for category in categorical:
    print(df[category].value_counts())
    print('-----')
# Out:
# lead_source
# organic_search    1251
# paid_ads          1140
# social_media      1055
# referral           790
# events             616
# NA                 148
# Name: count, dtype: int64
# -----
# industry
# technology       1173
# retail            925
# healthcare        840
# finance           720
# education         639
# manufacturing     463
# NA                240
# Name: count, dtype: int64
# -----
# employment_status
# employed         2633
# student           760
# self_employed     715
# unemployed        698
# NA                194
# Name: count, dtype: int64
# -----
# location
# north_america    1371
# europe           1149
# asia             1052
# south_america     749
# africa            471
# NA                208
# Name: count, dtype: int64
# -----

# %%
df['lead_source']=(df['lead_source']=='organic_search').astype(int)
df['industry']=(df['industry']=='technology').astype(int)
df['location']=(df['location']=='north_america').astype(int)
df['employment_status']=(df['employment_status']=='employed').astype(int)

# %%
df.tail(10)
# Out:
#       lead_source  industry  employment_status  location  annual_income  \
# 4990            1         0                  0         0        31691.0
# 4991            1         1                  0         0        70065.0
# 4992            0         0                  1         1        75940.0
# 4993            0         0                  0         1        28810.0
# 4994            1         0                  0         0        39984.0
# 4995            1         0                  1         0        45834.0
# 4996            0         1                  1         1        84831.0
# 4997            1         0                  1         0        53636.0
# 4998            0         1                  1         0        69430.0
# 4999            0         1                  1         0        81355.0
#
#       number_of_courses_viewed  interaction_count  lead_score  converted
# 4990                         3                  5        0.49          1
# ...

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(
    df_full_train, test_size=0.25, random_state=42
)
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train,y_val,y_test=df_train['converted'],df_val['converted'],df_test['converted']
X_train,X_val,X_test=df_train[['lead_source', 'industry', 'employment_status', 'location','annual_income', 'number_of_courses_viewed', 'interaction_count', 'lead_score']],df_val[['lead_source', 'industry', 'employment_status', 'location','annual_income', 'number_of_courses_viewed', 'interaction_count', 'lead_score']],df_test[['lead_source', 'industry', 'employment_status', 'location','annual_income', 'number_of_courses_viewed', 'interaction_count', 'lead_score']]

# %% [markdown]
# # Question 3
# Calculate the mutual information score between converted and other categorical variables in the dataset.
# - Use the training set only.
# - Round the scores to 2 decimals using round(score, 2).
# <br>
# Which of these variables has the biggest mutual information score?
#
# - industry
# - location
# - lead_source
# - employment_status

# %%
from sklearn.metrics import mutual_info_score

# Calculate the score for each column individually
mi_scores = {}
for col in X_train.columns:
    mi_scores[col] = round(mutual_info_score(y_train, X_train[col]),2)

print(mi_scores)
# Out:
# {'lead_source': 0.01, 'industry': 0.0, 'employment_status': 0.02, 'location': 0.0, 'annual_income': 0.6, 'number_of_courses_viewed': 0.08, 'interaction_count': 0.12, 'lead_score': 0.15}
# C:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:68: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Question 4
# Now let's train a logistic regression.
# Remember that we have several categorical variables in the dataset.
# - Include them using one-hot encoding.
# - Fit the model on the training dataset.
# - To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:<br>
# model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
# <br>
# Calculate the accuracy on the validation dataset and round it to 2 decimal digits.
# What accuracy did you get?

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred=model.predict(X_val)

# %%
baseline_acc=accuracy_score(y_pred,y_val)
print(baseline_acc)
# Out:
# 0.642

# %% [markdown]
# # Question 5
# - Let's find the least useful feature using the feature elimination technique.
# - Train a model using the same features and parameters as in Q4 (without rounding).
# - Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# - For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
# <br>
# Which of following feature has the smallest difference?
# <br>
#
# - 'lead_source'
# - 'number_of_courses_viewed'
# - 'interaction_count'

# %%
features = [
    'lead_source', 'industry', 'employment_status', 'location',
    'annual_income', 'number_of_courses_viewed', 'interaction_count', 'lead_score'
]


def predict(col_to_ignore):
    active_features = [f for f in features if f != col_to_ignore]
    model_elim = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
    model_elim.fit(df_train[active_features], y_train)
    y_pred = model_elim.predict(df_val[active_features])
    acc = accuracy_score(y_val, y_pred)
    diff = baseline_acc - acc
    print(f"Without {col_to_ignore:25} -> Accuracy: {acc} | Difference: {diff}")


for col in features:
    predict(col)
# Out:
# Without lead_source               -> Accuracy: 0.642 | Difference: 0.0
# Without industry                  -> Accuracy: 0.642 | Difference: 0.0
# Without employment_status         -> Accuracy: 0.644 | Difference: -0.0020000000000000018
# Without location                  -> Accuracy: 0.643 | Difference: -0.0010000000000000009
# Without annual_income             -> Accuracy: 0.714 | Difference: -0.07199999999999995
# Without number_of_courses_viewed  -> Accuracy: 0.642 | Difference: 0.0
# Without interaction_count         -> Accuracy: 0.597 | Difference: 0.04500000000000004
# Without lead_score                -> Accuracy: 0.642 | Difference: 0.0

# %% [markdown]
# # Question 6
# Now let's train a regularized logistic regression.
# Let's try the following values of the parameter C: [0.000001, 0.00001, 0.0001, 0.001].
# Train models using all the features as in Q4.
# Calculate the accuracy on the validation dataset and round it to 3 decimal digits.
# <br>
# Which of these C leads to the best accuracy on the validation set?

# %%
from sklearn.linear_model import LogisticRegressionCV

c=[0.000001, 0.00001, 0.0001, 0.001]
lr_cv = LogisticRegressionCV(Cs=c)
lr_cv.fit(X_train, y_train)

print(f"Best C value: {lr_cv.C_[0]}")
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:2092: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# C:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:2137: FutureWarning: The default value of the parameter 'scoring' will change from None, i.e. accuracy, to 'neg_log_loss' in version 1.11. To silence this warning, explicitly set the scoring parameter: scoring='neg_log_loss' for the new, scoring='accuracy' or scoring=None for the old default.
#   warnings.warn(
# ...
